# %%
# %matplotlib inline

# %%
import scikits.audiolab as audiolab
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /usr/local/lib/python2.7/dist-packages/scikits/audiolab/soundio/play.py:48: UserWarning: Could not import alsa backend; most probably, you did not have alsa headers when building audiolab
#   warnings.warn("Could not import alsa backend; most probably, "

# %%
# !wget http://www.nch.com.au/acm/11k16bitpcm.wav
# Out:
# --2014-06-04 16:00:11--  http://www.nch.com.au/acm/11k16bitpcm.wav
# Resolving www.nch.com.au...
# 66.39.106.2, 69.94.125.40
# Connecting to www.nch.com.au|66.39.106.2|:80...
# connected.
# HTTP request sent, awaiting response...
# 200 OK
# Length: 304578 (297K) [audio/x-wav]
# Saving to: `11k16bitpcm.wav.2'
#
#  0% [                                       ] 0           --.-K/s
# 11% [===>                                   ] 35,848       170K/s
# 45% [================>                      ] 138,656      320K/s
# 100%[======================================>] 304,578      492K/s   in 0.6s
# 2014-06-04 16:00:12 (492 KB/s) - `11k16bitpcm.wav.2' saved [304578/304578]

# %%
s = audiolab.sndfile("11k16bitpcm.wav")

# %%
frames = s.read_frames(s.get_nframes())

# %%
frames
# Out:
# array([  0.00000000e+00,  -6.10351562e-05,   0.00000000e+00, ...,
#         -4.27246094e-04,  -4.27246094e-04,   2.74658203e-04])

# %%
plt.plot(frames)

# %%
a = plt.specgram(frames)

# %%
# !aplay 11k16bitpcm.wav
# Out:
# Playing WAVE '11k16bitpcm.wav' : Signed 16 bit Little Endian, Rate 11025 Hz, Mono
# ^CAborted by signal Interrupt...
